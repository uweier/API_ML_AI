# %% [markdown]
# ## 路径规划API之代码输入输出调试
#
# [驾车路径规划](https://lbs.amap.com/api/webservice/guide/api/direction#driving)

# %%
import requests

key_api = 'bbefb4b3848672a7a43bf6a4003f19f2'

# 驾车路径规划
def driving(origin,destination):
    "步行路径规划"
    url = 'https://restapi.amap.com/v3/direction/driving?parameters'
    params = {
        'key' : key_api,
        'origin' : origin,
        'destination' : destination,
        'extensions':all,
    }
    response = requests.get(url,params = params)
    data = response.json()
    return data

# %%
driving("113.327023,23.13216","113.35208,23.139325")
# Out:
# {'status': '1',
#  'info': 'OK',
#  'infocode': '10000',
#  'count': '1',
#  'route': {'origin': '113.327023,23.13216',
#   'destination': '113.35208,23.139325',
#   'taxi_cost': '14',
#   'paths': [{'distance': '4344',
#     'duration': '1168',
#     'strategy': '速度最快',
#     'tolls': '0',
#     'toll_distance': '0',
#     'steps': [{'instruction': '向东行驶18米右转',
#       'orientation': '东',
#       'distance': '18',
#       'tolls': '0',
#       'toll_distance': '0',
#       'toll_road': [],
#       'duration': '13',
#       'polyline': '113.328033,23.132187;113.328217,23.132177',
#       'action': '右转',
#       'assistant_action': [],
#       'tmcs': [{'lcode': [],
#         'distance': '18',
#         'status': '未知',
#         'polyline': '113.328033,23.132187;113.328217,23.132177'}],
#       'cities': [{'name': '广州市',
#         'citycode': '020',
#         'adcode': '440100',
#         'districts': [{'name': '天河区', 'adcode': '440106'}]}]},
#      {'instruction': '沿体育东路向南行驶135米右转',
#       'orientation': '南',
#       'road': '体育东路',
#       'distance': '135',
#       'tolls': '0',
#       'toll_distance': '0',
#       'toll_road': [],
#       'duration': '65',
#       'polyline': '113.328217,23.132177;113.328133,23.130955',
#       'action': '右转',
#       'assistant_action': [],
#       'tmcs': [{'lcode': [],
#         'distance': '135',
#         'status': '畅通',
#         'polyline': '113.328217,23.132177;113.328133,23.130955'}],
#       'cities': [{'name': '广州市',
#         'citycode': '020',
#         'adcode': '440100',
#         'districts': [{'name': '天河区', 'adcode': '440106'}]}]},
#      {'instruction': '沿天河南一路向西行驶237米右转',
#       'orientation': '西',
#       'road': '天河南一路',
#       'distance': '237',
#       'tolls': '0',
#       'toll_distance': '0',
#       'toll_road': [],
#       'duration': '63',
#       'polyline': '113.328133,23.130955;113.327034,23.130999;113.326355,23.131025;113.325813,23.13102',
#       'action': '右转',
#       'assistant_action': [],
#       'tmcs': [{'lcode': [],
#         'distance': '113',
#         'status': '畅通',
#         'polyline': '113.328133,23.130955;113.327034,23.130999'},
#        {'lcode': [],
#         'distance': '124',
#         'status': '畅通',
#         'polyline': '113.327034,23.130999;113.326355,23.131025;113.325813,23.13102'}],
#       'cities': [{'name': '广州市',
#         'citycode': '020',
#         'adcode': '440100',
#         'districts': [{'name': '天河区', 'adcode': '440106'}]}]},
#      {'instruction': '沿正佳大街向北行驶267米右转',
#       'orientation': '北',
#       'road': '正佳大街',
#       'distance': '267',
#       'tolls': '0',
#       'toll_distance': '0',
#       'toll_road': [],
#       'duration': '162',
#       'polyline': '113.325813,23.13102;113.325844,23.131676;113.325867,23.132339;113.325874,23.132645;113.325882,23.13286;113.325912,23.133207;113.32592,23.133451',
#       'action': '右转',
#       'assistant_action': [],
#       'tmcs': [{'lcode': [],
#         'distance': '146',
#         'status': '拥堵',
#         'polyline': '113.325813,23.13102;113.325844,23.131676;113.325867,23.132339'},
#        {'lcode': [],
#         'distance': '33',
#         'status': '拥堵',
#         'polyline': '113.325867,23.132339;113.325874,23.132645'},
#        {'lcode': [],
#         'distance': '24',
#         'status': '拥堵',
#         'polyline': '113.325874,23.132645;113.325882,23.13286'},
#        {'lcode': [],
#         'distance': '38',
#         'status': '拥堵',
#         'polyline': '113.325882,23.13286;113.325912,23.133207'},
#        {'lcode': [],
#         'distance': '26',
#         'status': '缓行',
#         'polyline': '113.325912,23.133207;113.32592,23.133451'}],
#       'cities': [{'name': '广州市',
#         'citycode': '020',
#         'adcode': '440100',
#         'districts': [{'name': '天河区', 'adcode': '440106'}]}]},
#      {'instruction': '沿天河路向东行驶1.5千米靠左沿主路行驶',
#       'orientation': '东',
#       'road': '天河路',
#       'distance': '1509',
#       'tolls': '0',
#       'toll_distance': '0',
#       'toll_road': [],
#       'duration': '490',
#       'polyline': '113.32592,23.133451;113.326241,23.133429;113.326599,23.133408;113.327148,23.133389;113.328194,23.13332;113.328339,23.133316;113.328453,23.133303;113.330261,23.1332;113.331467,23.133165;113.331833,23.13316;113.332527,23.133112;113.333359,23.133091;113.334053,23.133112;113.334381,23.133142;113.334961,23.133293;113.334961,23.133293;113.335381,23.133411;113.335655,23.133476;113.336098,23.133575;113.33654,23.133652;113.336853,23.133698;113.337166,23.13378;113.337677,23.133934;113.337944,23.134041;113.338661,23.134357;113.339523,23.134701;113.339882,23.134863;113.340317,23.135073',
#       'action': '靠左',
#       'assistant_action': '沿主路行驶',
#       'tmcs': [{'lcode': [],
#         'distance': '33',
#         'status': '畅通',
#         'polyline': '113.32592,23.133451;113.326241,23.133429'},
#        {'lcode': [],
#         'distance': '36',
#         'status': '畅通',
#         'polyline': '113.326241,23.133429;113.326599,23.133408'},
#        {'lcode': [],
#         'distance': '164',
#         'status': '畅通',
#         'polyline': '113.326599,23.133408;113.327148,23.133389;113.328194,23.13332'},
#        {'lcode': [],
#         'distance': '25',
#         'status': '畅通',
#         'polyline': '113.328194,23.13332;113.328339,23.133316;113.328453,23.133303'},
#        {'lcode': [],
#         'distance': '185',
#         'status': '畅通',
#         'polyline': '113.328453,23.133303;113.330261,23.1332'},
#        {'lcode': [],
#         'distance': '123',
#         'status': '畅通',
#         'polyline': '113.330261,23.1332;113.331467,23.133165'},
#        {'lcode': [],
#         'distance': '37',
#         'status': '拥堵',
#         'polyline': '113.331467,23.133165;113.331833,23.13316'},
#        {'lcode': [],
#         'distance': '71',
#         'status': '拥堵',
#         'polyline': '113.331833,23.13316;113.332527,23.133112'},
#        {'lcode': [],
#         'distance': '86',
#         'status': '拥堵',
#         'polyline': '113.332527,23.133112;113.333359,23.133091'},
#        {'lcode': [],
#         'distance': '104',
#         'status': '拥堵',
#         'polyline': '113.333359,23.133091;113.334053,23.133112;113.334381,23.133142'},
#        {'lcode': [],
#         'distance': '61',
#         'status': '畅通',
#         'polyline': '113.334381,23.133142;113.334961,23.133293;113.334961,23.133293'},
#        {'lcode': [],
#         'distance': '45',
#         'status': '畅通',
#         'polyline': '113.334961,23.133293;113.335381,23.133411'},
#        {'lcode': [],
#         'distance': '29',
#         'status': '缓行',
#         'polyline': '113.335381,23.133411;113.335655,23.133476'},
#        {'lcode': [],
#         'distance': '93',
#         'status': '缓行',
#         'polyline': '113.335655,23.133476;113.336098,23.133575;113.33654,23.133652'},
#        {'lcode': [],
#         'distance': '65',
#         'status': '缓行',
#         'polyline': '113.33654,23.133652;113.336853,23.133698;113.337166,23.13378'},
#        {'lcode': [],
#         'distance': '84',
#         'status': '缓行',
#         'polyline': '113.337166,23.13378;113.337677,23.133934;113.337944,23.134041'},
#        {'lcode': [],
#         'distance': '81',
#         'status': '畅通',
#         'polyline': '113.337944,23.134041;113.338661,23.134357'},
#        {'lcode': [],
#         'distance': '137',
#         'status': '畅通',
#         'polyline': '113.338661,23.134357;113.339523,23.134701;113.339882,23.134863'},
#        {'lcode': [],
#         'distance': '50',
#         'status': '畅通',
#         'polyline': '113.339882,23.134863;113.340317,23.135073'}],
#       'cities': [{'name': '广州市',
#         'citycode': '020',
#         'adcode': '440100',
#         'districts': [{'name': '天河区', 'adcode': '440106'}]}]},
#      {'instruction': '沿天河路途径中山大道西向东行驶947米向左前方行驶',
#       'orientation': '东',
#       'road': '天河路',
#       'distance': '947',
#       'tolls': '0',
#       'toll_distance': '0',
#       'toll_road': [],
#       'duration': '108',
#       'polyline': '113.340317,23.135073;113.340393,23.13516;113.340759,23.135303;113.341049,23.135387;113.344292,23.136133;113.344566,23.136189;113.345139,23.136293;113.34536,23.13628;113.345543,23.13629;113.346016,23.136225;113.346779,23.13615;113.347229,23.136066;113.347931,23.135933;113.349327,23.135683',
#       'action': '向左前方行驶',
#       'assistant_action': [],
#       'tmcs': [{'lcode': [],
#         'distance': '536',
#         'status': '畅通',
#         'polyline': '113.340317,23.135073;113.340393,23.13516;113.340759,23.135303;113.341049,23.135387;113.344292,23.136133;113.344566,23.136189;113.345139,23.136293;113.34536,23.13628'},
#        {'lcode': [],
#         'distance': '20',
#         'status': '畅通',
#         'polyline': '113.34536,23.13628;113.345543,23.13629'},
#        {'lcode': [],
#         'distance': '173',
#         'status': '畅通',
#         'polyline': '113.345543,23.13629;113.346016,23.136225;113.346779,23.13615;113.347229,23.136066'},
#        {'lcode': [],
#         'distance': '73',
#         'status': '畅通',
#         'polyline': '113.347229,23.136066;113.347931,23.135933'},
#        {'lcode': [],
#         'distance': '145',
#         'status': '畅通',
#         'polyline': '113.347931,23.135933;113.349327,23.135683'}],
#       'cities': [{'name': '广州市',
#         'citycode': '020',
#         'adcode': '440100',
#         'districts': [{'name': '天河区', 'adcode': '440106'}]}]},
#      {'instruction': '沿中山大道西向东行驶180米左转调头',
#       'orientation': '东',
#       'road': '中山大道西',
#       'distance': '180',
#       'tolls': '0',
#       'toll_distance': '0',
#       'toll_road': [],
#       'duration': '47',
#       'polyline': '113.349327,23.135683;113.349442,23.135746;113.349487,23.135752;113.350159,23.13566;113.350807,23.135542;113.351051,23.1355',
#       'action': '左转调头',
#       'assistant_action': [],
#       'tmcs': [{'lcode': [],
#         'distance': '155',
#         'status': '畅通',
#         'polyline': '113.349327,23.135683;113.349442,23.135746;113.349487,23.135752;113.350159,23.13566;113.350807,23.135542'},
#        {'lcode': [],
#         'distance': '25',
#         'status': '畅通',
#         'polyline': '113.350807,23.135542;113.351051,23.1355'}],
#       'cities': [{'name': '广州市',
#         'citycode': '020',
#         'adcode': '440100',
#         'districts': [{'name': '天河区', 'adcode': '440106'}]}]},
#      {'instruction': '沿中山大道西向西行驶330米右转',
#       'orientation': '西',
#       'road': '中山大道西',
#       'distance': '330',
#       'tolls': '0',
#       'toll_distance': '0',
#       'toll_road': [],
#       'duration': '41',
#       'polyline': '113.351051,23.1355;113.351067,23.135565;113.350815,23.135611;113.349564,23.135841;113.349411,23.135916;113.349068,23.136038;113.348763,23.13611;113.347984,23.136253',
#       'action': '右转',
#       'assistant_action': [],
#       'tmcs': [{'lcode': [],
#         'distance': '7',
#         'status': '畅通',
#         'polyline': '113.351051,23.1355;113.351067,23.135565'},
#        {'lcode': [],
#         'distance': '25',
#         'status': '畅通',
#         'polyline': '113.351067,23.135565;113.350815,23.135611'},
#        {'lcode': [],
#         'distance': '148',
#         'status': '畅通',
#         'polyline': '113.350815,23.135611;113.349564,23.135841;113.349411,23.135916'},
#        {'lcode': [],
#         'distance': '69',
#         'status': '畅通',
#         'polyline': '113.349411,23.135916;113.349068,23.136038;113.348763,23.13611'},
#        {'lcode': [],
#         'distance': '81',
#         'status': '畅通',
#         'polyline': '113.348763,23.13611;113.347984,23.136253'}],
#       'cities': [{'name': '广州市',
#         'citycode': '020',
#         'adcode': '440100',
#         'districts': [{'name': '天河区', 'adcode': '440106'}]}]},
#      {'instruction': '向北行驶54米右转',
#       'orientation': '北',
#       'distance': '54',
#       'tolls': '0',
#       'toll_distance': '0',
#       'toll_road': [],
#       'duration': '24',
#       'polyline': '113.347984,23.136253;113.348,23.136528;113.348,23.136749',
#       'action': '右转',
#       'assistant_action': [],
#       'tmcs': [{'lcode': [],
#         'distance': '30',
#         'status': '未知',
#         'polyline': '113.347984,23.136253;113.348,23.136528'},
#        {'lcode': [],
#         'distance': '24',
#         'status': '未知',
#         'polyline': '113.348,23.136528;113.348,23.136749'}],
#       'cities': [{'name': '广州市',
#         'citycode': '020',
#         'adcode': '440100',
#         'districts': [{'name': '天河区', 'adcode': '440106'}]}]},
#      {'instruction': '向东行驶202米左转',
#       'orientation': '东',
#       'distance': '202',
#       'tolls': '0',
#       'toll_distance': '0',
#       'toll_road': [],
#       'duration': '57',
#       'polyline': '113.348,23.136749;113.348198,23.136744;113.348793,23.136753;113.349083,23.136766;113.349411,23.136766;113.349884,23.13677;113.350006,23.136789',
#       'action': '左转',
#       'assistant_action': [],
#       'tmcs': [{'lcode': [],
#         'distance': '19',
#         'status': '未知',
#         'polyline': '113.348,23.136749;113.348198,23.136744'},
#        {'lcode': [],
#         'distance': '60',
#         'status': '未知',
#         'polyline': '113.348198,23.136744;113.348793,23.136753'},
#        {'lcode': [],
#         'distance': '30',
#         'status': '未知',
#         'polyline': '113.348793,23.136753;113.349083,23.136766'},
#        {'lcode': [],
#         'distance': '33',
#         'status': '未知',
#         'polyline': '113.349083,23.136766;113.349411,23.136766'},
#        {'lcode': [],
#         'distance': '60',
#         'status': '未知',
#         'polyline': '113.349411,23.136766;113.349884,23.13677;113.350006,23.136789'}],
#       'cities': [{'name': '广州市',
#         'citycode': '020',
#         'adcode': '440100',
#         'districts': [{'name': '天河区', 'adcode': '440106'}]}]},
#      {'instruction': '向北行驶230米进入环岛绕环岛右转',
#       'orientation': '北',
#       'distance': '230',
#       'tolls': '0',
#       'toll_distance': '0',
#       'toll_road': [],
#       'duration': '39',
#       'polyline': '113.350006,23.136789;113.349976,23.137205;113.349945,23.13759;113.34993,23.138203;113.349915,23.138342;113.349884,23.138866',
#       'action': '进入环岛',
#       'assistant_action': '绕环岛右转',
#       'tmcs': [{'lcode': [],
#         'distance': '89',
#         'status': '未知',
#         'polyline': '113.350006,23.136789;113.349976,23.137205;113.349945,23.13759'},
#        {'lcode': [],
#         'distance': '83',
#         'status': '未知',
#         'polyline': '113.349945,23.13759;113.34993,23.138203;113.349915,23.138342'},
#        {'lcode': [],
#         'distance': '58',
#         'status': '未知',
#         'polyline': '113.349915,23.138342;113.349884,23.138866'}],
#       'cities': [{'name': '广州市',
#         'citycode': '020',
#         'adcode': '440100',
#         'districts': [{'name': '天河区', 'adcode': '440106'}]}]},
#      {'instruction': '向东北行驶28米离开环岛',
#       'orientation': '东北',
#       'distance': '28',
#       'tolls': '0',
#       'toll_distance': '0',
#       'toll_road': [],
#       'duration': '18',
#       'polyline': '113.349884,23.138866;113.349983,23.138889;113.350037,23.138924;113.35006,23.138981;113.35006,23.139021',
#       'action': '离开环岛',
#       'assistant_action': [],
#       'tmcs': [{'lcode': [],
#         'distance': '28',
#         'status': '未知',
#         'polyline': '113.349884,23.138866;113.349983,23.138889;113.350037,23.138924;113.35006,23.138981;113.35006,23.139021'}],
#       'cities': [{'name': '广州市',
#         'citycode': '020',
#         'adcode': '440100',
#         'districts': [{'name': '天河区', 'adcode': '440106'}]}]},
#      {'instruction': '沿紫荆中路向东行驶207米到达目的地',
#       'orientation': '东',
#       'road': '紫荆中路',
#       'distance': '207',
#       'tolls': '0',
#       'toll_distance': '0',
#       'toll_road': [],
#       'duration': '41',
#       'polyline': '113.35006,23.139021;113.350281,23.13905;113.350632,23.139071;113.351074,23.13912;113.351913,23.139206;113.352089,23.139217',
#       'action': [],
#       'assistant_action': '到达目的地',
#       'tmcs': [{'lcode': [],
#         'distance': '22',
#         'status': '未知',
#         'polyline': '113.35006,23.139021;113.350281,23.13905'},
#        {'lcode': [],
#         'distance': '81',
#         'status': '未知',
#         'polyline': '113.350281,23.13905;113.350632,23.139071;113.351074,23.13912'},
#        {'lcode': [],
#         'distance': '86',
#         'status': '未知',
#         'polyline': '113.351074,23.13912;113.351913,23.139206'},
#        {'lcode': [],
#         'distance': '18',
#         'status': '未知',
#         'polyline': '113.351913,23.139206;113.352089,23.139217'}],
#       'cities': [{'name': '广州市',
#         'citycode': '020',
#         'adcode': '440100',
#         'districts': [{'name': '天河区', 'adcode': '440106'}]}]}],
#     'restriction': '0',
#     'traffic_lights': '6'}]}}
